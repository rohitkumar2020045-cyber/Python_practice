# %%
print("Today is my first program")

# %%
import builtins
print(dir(builtins))

# %%
name = "aman"  #variables
age = 45
height =5.5
is_student = True
subject= ["Math","Physics","CS"]
cordinates =(2,220,22)
student_info={"name": "aman","age":45}
unique_ids ={120,22,302}
print(name,age,height,is_student)
print(subject,cordinates,student_info)
print(unique_ids)

# %%
list1=[12,5,23,5,54] #List
print(list1)
print(list1[3])
list1.append(00)
list1.insert(1,55)
list1[2] =88
list1.remove(5)
list1.pop()
print(list1)

# %%
num =(2,5,6,3,6,44) #tuple
print(num)
print(num[0])
print(num[3])
print(num[1:3])
print(num.count(3))
print(num.index(44))

# %%
students ={"Name": "Rahul"  #dictionary
,"age": 21,
"course": "B.Tech",
"city": "Lucknow"
}
print(students)
print(students["age"])
students["coleege"]="SMS LUCKNOW"
students["age"]=22
print(students)

# %%
SMS={
    "Branch":"B tech",
    "Course":"CSE",
    "section":"B"
}
print(SMS)
print(SMS["Course"])
SMS["Name"]="Roni"
print(SMS)

# %%
numbers={2,3,4,6,8,6,2,4  #Sets
}
print(numbers)


A={1,2,6,5,4,52,5}
B={3,6,9,4,5,0}

print(A|B) #union
print(A&B)  #intersection
print(A-B)
print(A^B)

# %%
Q="34"


B=int(Q)
C=float(Q)
print(B,C)
A="def"


X=55.2
Y=int(X)
Z=str(Y)
print(Z)

# %%
a=float(input("Enter first number:"))
b=float(input("Enter second number:"))

print("Addition",a+b)
print("substraction",a-b)
print("Multiplication",a*b)
print("Division",a/b)
print("Floor Division",a//b)
print("Modulus",a%b)

# %%
a= 22  #relational operator
b= 52
c=229

d=float(input("Enter first num:"))
f=float(input("Enter sec  num:"))

print(a==b)
print(a!=b)
print(a<b)
print(a>b)
print(a<=c)
print(a>=c)

# %%
p= 0    #logicl operator
q= 5

print(p and q)
print(p or q)
print(not q)

# %%
c=22 #assignment operator
c +=2
print(c)
c -=3
print(c)

c*=3
print(c)
c //=3
print(c)

# %%
#membership and identity operator
Fruits={
    
    "apple","banana","guava"
}
print("apple" in Fruits)
print("papaya" not in Fruits)

x={1,2,3}
y={1,5,3}
print(x is y)
print(x is not y)
print(x==y)

# %%
#conditional operator
marks = 40
if marks >= 40:
    print("you are passed")
else:
    print("you are failed")

# %%
marks = int(input("enter your marks"))

if marks >= 90:
    grade ="A"
elif marks >= 75:
    grade= "B"
elif marks >=50:
    grade= "C"
else:
    grade= "F"
print("Grade",grade)

# %%
age= int(input("enter yor age"))

has_id = True

if age >= 18:
    if has_id:
        print("Entry allowed")

    else:
        print("Id required")

else:
    print("Entry denied:must be 18+")

# %%
a= float(input("Enter first num: "))
b = float(input("Enter second num: "))
if a>b:
    a+= 1
elif a<b:
    b+=1
print(a,b)

# %%
m = int(input("Enter value of m: "))
x = int(input("Enter value of x: "))
c = int(input("Enter value of c: "))

y = m*x + c**2

print("result", y)

# %%
for i in range(0,10):
    print("Iteration",i)

# %%
stationary =["book","pencil","copies","rubber","scale"]

for st in stationary:
    print(st,end=" ")
#print(stationary)

# %%
count = 1
while count<=5:
    print("count",count)
    count+=1

# %%
a = "Hello"
b = "World"
print(b and a,a and b)

# %%
for i in range(1,10):
    if i ==7:
        break
    print(i)

# %%
#loop with using range() function
#Wap to print a 1 to 10 numbers using loop through range function
#Star : indexing 0 start begining and
#stop:do not print stop
# step: gap
for i in range(1,11):
    print(i)

# %%
list =[10,20,30,40]

for num in list :
    print(num*num)

# %%
for num in list:
    print(num**2)

# %%
#wap to calculate the average in a list

num =[2,5,3,6,4]
total = 0
for no in num:
    total =total+no
average= total / len(num)
print(average)

# %%
#while loop 

i = 1
while i <= 5:
    print(i)
    i= i+1

# %%
#wap to print odd and even numbers ussing for loop range and conditional statement

for i in range(1,20):
    if i % 2 ==0:
        print(i, "is even", end =" | ")

    else:
        print(i, "is odd", end = " | ")

# %%
#continue statement

for i in range(1,10):
    if i ==3:
        continue
    print(i)

# %%
for i in range(1,10):
    if i % 2 ==0:
        continue
    print(i)

# %%
#slicing

text = "Python"
# print(text[0:3])
# print(text[::-1])
for i in range(len(text)):
    if i==4:
        continue
print(text[2:])

# %%
def greet():    # def is keyword used to create a function
    print("Hello , Today class is online")
#funtional calling, driver code
greet()

# %%
#function with parameter
def add(a,b):
    result = a+ b
    print(result)
def sub(a,b):
    result = a-b
    print(result)
add(10,6)
sub(10,6)

# %%
#Function with return value

def add(a, b):
    return a+b
result=add(20,30)

print(result)

# %%
x = [1,2,3,4,5]
y = x 

y.append(4)
print(x)
print(y)

# %%
x = [1,20,3,0,55,3]
y = x.copy()

y.append(100)

print(y)
print(x)

# %%
list = [1, 2, 3, 4, 5]  #min, max function
print(min(list))
print(max(list))

# %%
list1 = [2,3,4,9,11]
print(list(enumerate(list1)))

# %%
def add(a , b):  
    result = a + b
    print(result)
def sub(a , b):
    result = a - b
    print(result)
def mul(a,b):
    result = a*b
    print(result)
def div(a , b):
    result = a/b
    print(result)
#Function calling
add(2,5)
sub(5,3)
mul(5,5)
div(55,11)

# %%
def check_odd(num):
    if num % 2 != 0:
        return num, "is odd"
    else:
        return num, "is even"
n = int(input("Enter a number: "))
result = check_odd(n)
print(result)

# %%
def check_prime(num):
    if num < 2:
        return False
    for i in range(2, num):
        if (num % i) == 0:
                return False
    return True

n = int(input("Enter a number: "))
if check_prime(n):
    print(n, "is prime")
else:       
    print(n, "is not prime")

# %%
# step1: outer loop >> rows
# step2: inner loop >> columns

rows = 5
for i in range(1, 6):
    for j in range(1,i+1):
        print("$" ,end=" ")
    print()

# %%
rows = 5
for i in range(5, 0 , -1):
    for j in range(1, i+1):
        print("$", end=" ")
    print()

# %%
row = 4
for i in range(1, 5):
    for j in range(1,5):
        print("*",end=" ")
    print()

# %%
for i in range(1,6):
    for j in range(1,i+1):
        print(j, end=" ")
    print()

# %%
for i in range(6,0,-1):
    for j in range(1,i):
        print(j, end =" ")
    print()

# %%
for i in range(5,0,-1):
    for j in range(i,0,-1):
        print(j, end =" ")
    print()

# %%
list =[2,5,6,9,12,20]
print(len(list))
list[4]=66
print(list)

list.append(50)
print(list)

list.insert(0,1)
print(list)

list.extend([0,33,55])
print(list)

list.pop(1) #pop elememt by index
print(list)

list.sort()
print(list)

list.reverse()
print(list)

print(list[4])

list.remove(5) #remove element
print(list)

print(sum(list)) #sum of all elements in list

# %%
for i in range(1,6):
    for j in range(i,i+1):
        print("*",end =" ")
        if i ==5:
            print("* " * (i-1))
        print()
# Out:
# *
# *
# *
# *
# * * * * *

# %%
n = 5
for i in range(n):
    if i == n - 1:
        
        print("* " * rows)
    else:
       
        print("*")
# Out:
# *
# *
# *
# *
# * * * * *
