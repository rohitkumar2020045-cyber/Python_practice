# %%
#Ques 2:

rows = 6

for i in range(1,8):
    for j in range(1,i):
        print(j, end=" ")

    print()

# %%
#Reverse a num using while loop:

n= int(input("Enter a number:"))
temp = 0
while n > 0:
    temp = temp * 10 + n % 10
    n = n // 10
print("Reversed number:", temp)
# Out:
# Reversed number: 365

# %%
a= int(input("Enter a value"))
b =int(input("Enter a second value"))

print("a= ",b ,"b= ",a)
# Out:
# a=  6 b=  5

# %%
a = int(input("Enter 1st num : "))
b = int(input("Enter 2nd num :"))
c = int(input("Enter 3rd num :"))

if a > b and a > c:
    print("a is greater",a)
elif b > a and b > c:
    print("b is greater",b)
elif c > a and c> b:
    print("c is greater",c)

else:
    print("any two number are equal or all numbers are equal")
